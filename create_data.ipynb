# %%
countries = [
    ('US', 'United States'),
    ('AF', 'Afghanistan'),
    ('AL', 'Albania'),
    ('DZ', 'Algeria'),
    ('AS', 'American Samoa'),
    ('AD', 'Andorra'),
    ('AO', 'Angola'),
    ('AI', 'Anguilla'),
    ('AQ', 'Antarctica'),
    ('AG', 'Antigua And Barbuda'),
    ('AR', 'Argentina'),
    ('AM', 'Armenia'),
    ('AW', 'Aruba'),
    ('AU', 'Australia'),
    ('AT', 'Austria'),
    ('AZ', 'Azerbaijan'),
    ('BS', 'Bahamas'),
    ('BH', 'Bahrain'),
    ('BD', 'Bangladesh'),
    ('BB', 'Barbados'),
    ('BY', 'Belarus'),
    ('BE', 'Belgium'),
    ('BZ', 'Belize'),
    ('BJ', 'Benin'),
    ('BM', 'Bermuda'),
    ('BT', 'Bhutan'),
    ('BO', 'Bolivia'),
    ('BA', 'Bosnia And Herzegowina'),
    ('BW', 'Botswana'),
    ('BV', 'Bouvet Island'),
    ('BR', 'Brazil'),
    ('BN', 'Brunei Darussalam'),
    ('BG', 'Bulgaria'),
    ('BF', 'Burkina Faso'),
    ('BI', 'Burundi'),
    ('KH', 'Cambodia'),
    ('CM', 'Cameroon'),
    ('CA', 'Canada'),
    ('CV', 'Cape Verde'),
    ('TD', 'Chad'),
    ('CL', 'Chile'),
    ('CN', 'China'),
    ('CX', 'Christmas Island'),
    ('CC', 'Cocos Islands'),
    ('CO', 'Colombia'),
    ('KM', 'Comoros'),
    ('CG', 'Congo'),
    ('CK', 'Cook Islands'),
    ('CR', 'Costa Rica'),
    ('HR', 'Croatia'),
    ('CU', 'Cuba'),
    ('CY', 'Cyprus'),
    ('CZ', 'Czech Republic'),
    ('DK', 'Denmark'),
    ('DJ', 'Djibouti'),
    ('DM', 'Dominica'),
    ('DO', 'Dominican Republic'),
    ('TP', 'East Timor'),
    ('EC', 'Ecuador'),
    ('EG', 'Egypt'),
    ('SV', 'El Salvador'),
    ('GQ', 'Equatorial Guinea'),
    ('ER', 'Eritrea'),
    ('EE', 'Estonia'),
    ('ET', 'Ethiopia'),
    ('FJ', 'Fiji'),
    ('FI', 'Finland'),
    ('FR', 'France'),
    ('GA', 'Gabon'),
    ('GM', 'Gambia'),
    ('GE', 'Georgia'),
    ('DE', 'Germany'),
    ('GH', 'Ghana'),
    ('GI', 'Gibraltar'),
    ('GR', 'Greece'),
    ('GL', 'Greenland'),
    ('GD', 'Grenada'),
    ('GP', 'Guadeloupe'),
    ('GU', 'Guam'),
    ('GT', 'Guatemala'),
    ('GN', 'Guinea'),
    ('GW', 'Guinea-bissau'),
    ('GY', 'Guyana'),
    ('HT', 'Haiti'),
    ('HN', 'Honduras'),
    ('HK', 'Hong Kong'),
    ('HU', 'Hungary'),
    ('IS', 'Iceland'),
    ('IN', 'India'),
    ('ID', 'Indonesia'),
    ('IR', 'Iran'),
    ('IQ', 'Iraq'),
    ('IE', 'Ireland'),
    ('IL', 'Israel'),
    ('IT', 'Italy'),
    ('JM', 'Jamaica'),
    ('JP', 'Japan'),
    ('JO', 'Jordan'),
    ('KZ', 'Kazakhstan'),
    ('KE', 'Kenya'),
    ('KI', 'Kiribati'),
    ('KP', 'Korea (North)'),
    ('KR', 'Korea (South)'),
    ('KW', 'Kuwait'),
    ('KG', 'Kyrgyzstan'),
    ('LA', 'Laos'),
    ('LV', 'Latvia'),
    ('LB', 'Lebanon'),
    ('LS', 'Lesotho'),
    ('LR', 'Liberia'),
    ('LY', 'Libya'),
    ('LI', 'Liechtenstein'),
    ('LT', 'Lithuania'),
    ('LU', 'Luxembourg'),
    ('MO', 'Macau'),
    ('MK', 'Macedonia'),
    ('MG', 'Madagascar'),
    ('MW', 'Malawi'),
    ('MY', 'Malaysia'),
    ('MV', 'Maldives'),
    ('ML', 'Mali'),
    ('MT', 'Malta'),
    ('MH', 'Marshall Islands'),
    ('MQ', 'Martinique'),
    ('MR', 'Mauritania'),
    ('MU', 'Mauritius'),
    ('YT', 'Mayotte'),
    ('MX', 'Mexico'),
    ('FM', 'Micronesia'),
    ('MD', 'Moldova'),
    ('MC', 'Monaco'),
    ('MN', 'Mongolia'),
    ('MS', 'Montserrat'),
    ('MA', 'Morocco'),
    ('MZ', 'Mozambique'),
    ('MM', 'Myanmar'),
    ('NA', 'Namibia'),
    ('NR', 'Nauru'),
    ('NP', 'Nepal'),
    ('NL', 'Netherlands'),
    ('AN', 'Netherlands Antilles'),
    ('NC', 'New Caledonia'),
    ('NZ', 'New Zealand'),
    ('NI', 'Nicaragua'),
    ('NE', 'Niger'),
    ('NG', 'Nigeria'),
    ('NU', 'Niue'),
    ('NF', 'Norfolk Island'),
    ('MP', 'Northern Mariana Islands'),
    ('NO', 'Norway'),
    ('OM', 'Oman'),
    ('PK', 'Pakistan'),
    ('PW', 'Palau'),
    ('PA', 'Panama'),
    ('PG', 'Papua New Guinea'),
    ('PY', 'Paraguay'),
    ('PE', 'Peru'),
    ('PH', 'Philippines'),
    ('PN', 'Pitcairn'),
    ('PL', 'Poland'),
    ('PT', 'Portugal'),
    ('PR', 'Puerto Rico'),
    ('QA', 'Qatar'),
    ('RE', 'Reunion'),
    ('RO', 'Romania'),
    ('RU', 'Russian Federation'),
    ('RW', 'Rwanda'),
    ('KN', 'Saint Kitts And Nevis'),
    ('LC', 'Saint Lucia'),
    ('VC', 'St Vincent/Grenadines'),
    ('WS', 'Samoa'),
    ('SM', 'San Marino'),
    ('ST', 'Sao Tome'),
    ('SA', 'Saudi Arabia'),
    ('SN', 'Senegal'),
    ('SC', 'Seychelles'),
    ('SL', 'Sierra Leone'),
    ('SG', 'Singapore'),
    ('SK', 'Slovakia'),
    ('SI', 'Slovenia'),
    ('SB', 'Solomon Islands'),
    ('SO', 'Somalia'),
    ('ZA', 'South Africa'),
    ('ES', 'Spain'),
    ('LK', 'Sri Lanka'),
    ('SH', 'St. Helena'),
    ('PM', 'St.Pierre'),
    ('SD', 'Sudan'),
    ('SR', 'Suriname'),
    ('SZ', 'Swaziland'),
    ('SE', 'Sweden'),
    ('CH', 'Switzerland'),
    ('SY', 'Syrian Arab Republic'),
    ('TW', 'Taiwan'),
    ('TJ', 'Tajikistan'),
    ('TZ', 'Tanzania'),
    ('TH', 'Thailand'),
    ('TG', 'Togo'),
    ('TK', 'Tokelau'),
    ('TO', 'Tonga'),
    ('TT', 'Trinidad And Tobago'),
    ('TN', 'Tunisia'),
    ('TR', 'Turkey'),
    ('TM', 'Turkmenistan'),
    ('TV', 'Tuvalu'),
    ('UG', 'Uganda'),
    ('UA', 'Ukraine'),
    ('AE', 'United Arab Emirates'),
    ('UK', 'United Kingdom'),
    ('UY', 'Uruguay'),
    ('UZ', 'Uzbekistan'),
    ('VU', 'Vanuatu'),
    ('VA', 'Vatican City State'),
    ('VE', 'Venezuela'),
    ('VN', 'Viet Nam'),
    ('VG', 'Virgin Islands (British)'),
    ('VI', 'Virgin Islands (U.S.)'),
    ('YE', 'Yemen'),
    ('YU', 'Yugoslavia'),
    ('ZR', 'Zaire'),
    ('ZM', 'Zambia'),
    ('ZW', 'Zimbabwe')
]

# %%
from faker import Faker
import pymongo
import pandas as pd
import random

fake = Faker()

client = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = client["Vulns"]

teams_col = mydb["teams"]
assets_col = mydb["assets"]

# %% [markdown]
# # Times

# %%
teams = []

for i in range(15):
    templ_team = {"name": '', "members": []}
    
    templ_team["name"] = random.choice(countries)[1]

    
    for i in range(6):
        templ_team["members"].append(fake.name())
        
    teams.append(templ_team)

# %%
teams_col.insert_many(teams)
# Out:
# InsertManyResult([ObjectId('66c50967bb30dec7b332f6b6'), ObjectId('66c50967bb30dec7b332f6b7'), ObjectId('66c50967bb30dec7b332f6b8'), ObjectId('66c50967bb30dec7b332f6b9'), ObjectId('66c50967bb30dec7b332f6ba'), ObjectId('66c50967bb30dec7b332f6bb'), ObjectId('66c50967bb30dec7b332f6bc'), ObjectId('66c50967bb30dec7b332f6bd'), ObjectId('66c50967bb30dec7b332f6be'), ObjectId('66c50967bb30dec7b332f6bf'), ObjectId('66c50967bb30dec7b332f6c0'), ObjectId('66c50967bb30dec7b332f6c1'), ObjectId('66c50967bb30dec7b332f6c2'), ObjectId('66c50967bb30dec7b332f6c3'), ObjectId('66c50967bb30dec7b332f6c4')], acknowledged=True)

# %%
teams
# Out:
# [{'name': 'Norfolk Island',
#   'members': ['Amanda Lynch',
#    'Randall Henderson',
#    'Kim Solis',
#    'Mark Conrad',
#    'Gregory Coleman',
#    'Francisco Rivera'],
#   '_id': ObjectId('66c50967bb30dec7b332f6b6')},
#  {'name': 'Morocco',
#   'members': ['Elaine Good',
#    'Chad Crawford',
#    'Brandon Chavez',
#    'Amy Romero',
#    'Renee Turner',
#    'Veronica Waters'],
#   '_id': ObjectId('66c50967bb30dec7b332f6b7')},
#  {'name': 'Jamaica',
#   'members': ['Jennifer Wallace',
#    'Mark Smith',
#    'Tanya Hancock',
#    'Christian Friedman',
#    'David Brown',
#    'Tiffany Taylor'],
#   '_id': ObjectId('66c50967bb30dec7b332f6b8')},
#  {'name': 'Niue',
#   'members': ['Jennifer Nguyen',
#    'Julia Lamb',
#    'Debra Rivas',
#    'Lisa Taylor',
#    'Susan Graves',
#    'Jessica Johnson'],
#   '_id': ObjectId('66c50967bb30dec7b332f6b9')},
#  {'name': 'Kazakhstan',
#   'members': ['Susan Frederick',
#    'Richard Rodriguez',
#    'Matthew Lam',
#    'Mariah Lopez',
# ...

# %% [markdown]
# # Assets

# %%
teams_countries = []

for i in list(teams_col.find({}, { "name": 1 ,"_id":0})):
    teams_countries.append(i["name"])

teams_countries
# Out:
# ['Norfolk Island',
#  'Morocco',
#  'Jamaica',
#  'Niue',
#  'Kazakhstan',
#  'Bangladesh',
#  'Malta',
#  'Argentina',
#  'Morocco',
#  'Bhutan',
#  'Malaysia',
#  'Australia',
#  'France',
#  'Ireland',
#  'Mauritius']

# %%
from faker.providers import internet
import uuid
fake = Faker()
fake.add_provider(internet)


seen = []
assets = []

for i in range(20_000):

    hostname = str(uuid.uuid4())

    
    while True:
        ip = fake.ipv4_private()
        
        if ip not in seen:
            seen.append(ip)
            break
        

    
    n = random.randint(1,5)
    rand_teams = random.sample(teams_countries, n)


    asset = {
        "hostname": hostname,
        "ip": ip,
        "team": rand_teams ,
        "ACR": round(random.uniform(0,10), 1)
    }
    
    assets.append(asset)

# %%
assets_col.insert_many(assets)
# Out:
# InsertManyResult([ObjectId('66c510b5bb30dec7b332f6c6'), ObjectId('66c510b5bb30dec7b332f6c7'), ObjectId('66c510b5bb30dec7b332f6c8'), ObjectId('66c510b5bb30dec7b332f6c9'), ObjectId('66c510b5bb30dec7b332f6ca'), ObjectId('66c510b5bb30dec7b332f6cb'), ObjectId('66c510b5bb30dec7b332f6cc'), ObjectId('66c510b5bb30dec7b332f6cd'), ObjectId('66c510b5bb30dec7b332f6ce'), ObjectId('66c510b5bb30dec7b332f6cf'), ObjectId('66c510b5bb30dec7b332f6d0'), ObjectId('66c510b5bb30dec7b332f6d1'), ObjectId('66c510b5bb30dec7b332f6d2'), ObjectId('66c510b5bb30dec7b332f6d3'), ObjectId('66c510b5bb30dec7b332f6d4'), ObjectId('66c510b5bb30dec7b332f6d5'), ObjectId('66c510b5bb30dec7b332f6d6'), ObjectId('66c510b5bb30dec7b332f6d7'), ObjectId('66c510b5bb30dec7b332f6d8'), ObjectId('66c510b5bb30dec7b332f6d9'), ObjectId('66c510b5bb30dec7b332f6da'), ObjectId('66c510b5bb30dec7b332f6db'), ObjectId('66c510b5bb30dec7b332f6dc'), ObjectId('66c510b5bb30dec7b332f6dd'), ObjectId('66c510b5bb30dec7b332f6de'), ObjectId('66c510b5bb30dec7b332
# ...

# %% [markdown]
# # Assets Neo4j

# %%
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"  
username = "neo4j"  
password = "" 

driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
driver.verify_connectivity()

# %%
def insert_nodes(nodes):
    with driver.session() as session:
        for node in nodes:
            query = """
            CREATE (n:Asset {
                hostname: $hostname,
                ip: $ip,
                ACR: $acr
            })
            WITH n
            UNWIND $team AS team
            MERGE (t:Team {name: team})
            MERGE (n)-[:Pertence]->(t)
            """
            session.run(query, hostname=node['hostname'], ip=node['ip'], acr=node['ACR'], team=node['team'])

# %%
all_assets =list(assets_col.find(projection={"_id":False}))

insert_nodes(all_assets)

# %%
for asset in all_assets:
    

    n = random.randint(1,10)


    rand_conections = random.sample(all_assets, n)

    for con in rand_conections:
        
        with driver.session() as session:
            query = """
            MATCH (a1:Asset {hostname: $hostname1}), (a2:Asset {hostname: $hostname2})
            CREATE (a1)-[:conectado_com]->(a2)
            """
            session.run(query, hostname1=asset["hostname"], hostname2=con["hostname"])

# %% [markdown]
# # Exports

# %%
cve = pd.read_csv("cve.csv").rename(columns={"Unnamed: 0": "cve"}).to_dict("records")

for vuln in cve:

    cvss = vuln["cvss"]
    
    severity = ""
    if cvss < 2:     
        severity = "Info"
    
    elif cvss >= 2 and cvss < 5:
        severity = "Low"
    
    elif cvss >= 5 and cvss < 7:
        severity = "Medium"
    
    elif cvss >= 7 and cvss < 8.5:
        severity = "High"
    
    elif cvss >= 8.5:
        severity = "Critical"


    vuln.update({"severity": severity})

# %%
cve
# Out:
# [{'cve': 'CVE-2019-16548',
#   'mod_date': '2019-11-21 15:15:00',
#   'pub_date': '2019-11-21 15:15:00',
#   'cvss': 6.8,
#   'cwe_code': 352,
#   'cwe_name': ' Cross-Site Request Forgery (CSRF)',
#   'summary': 'A cross-site request forgery vulnerability in Jenkins Google Compute Engine Plugin 4.1.1 and earlier in ComputeEngineCloud#doProvision could be used to provision new agents.',
#   'access_authentication': nan,
#   'access_complexity': nan,
#   'access_vector': nan,
#   'impact_availability': nan,
#   'impact_confidentiality': nan,
#   'impact_integrity': nan,
#   'severity': 'Medium'},
#  {'cve': 'CVE-2019-16547',
#   'mod_date': '2019-11-21 15:15:00',
#   'pub_date': '2019-11-21 15:15:00',
#   'cvss': 4.0,
#   'cwe_code': 732,
#   'cwe_name': ' Incorrect Permission Assignment for Critical Resource',
# ...

# %%
for i in range(1_000_000):
    
    mydb["export1"].insert_one({"asset":random.choice(all_assets), "vuln": random.choice(cve)})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 for i in range(9_000_000):
# ----> 2     mydb["export1"].insert_one({"asset":random.choice(all_assets), "vuln": random.choice(cve)})
#
# File /usr/local/lib/python3.10/dist-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
# ...
